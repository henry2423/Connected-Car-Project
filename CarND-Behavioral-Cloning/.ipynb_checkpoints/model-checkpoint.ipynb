# %%
# load in the data
import pandas as pd
track_log = pd.read_csv('../../Dataset/train/driving_log.csv',names=['Center','Left','Right','Steering Angle','Throttle','Break','Speed'], skiprows=1)
track1_log = pd.read_csv('../../Dataset/test/driving_log.csv',names=['Center','Left','Right','Steering Angle','Throttle','Break','Speed'], skiprows=1)
#track2_log = pd.read_csv('../../data4/driving_log.csv',names=['Center','Left','Right','Steering Angle','Throttle','Break','Speed'], skiprows=1)
track3_log = pd.read_csv('../../data5/driving_log.csv',names=['Center','Left','Right','Steering Angle','Throttle','Break','Speed'], skiprows=1)

#combine track1 and track2 data
combine = [track_log, track1_log, track3_log]
#make the combine ignore the index number
track_log = pd.concat(combine, ignore_index=True) 

print(track_log.shape)
# Out:
# (17302, 7)

# %%
#load in the img by csv_data
import cv2
import numpy as np

def load_in_img(img_location):
    
    #folder name has save in img_location
    imageLocation = '../../'+img_location
    image = cv2.imread(imageLocation,cv2.IMREAD_COLOR) # BGR

    if (image is None):
        print(imageLocation)
        
    image = image[45:-9,::]
    image = cv2.resize(image, (200,66), fx=0, fy=0)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # BGR to RGB
    return image

numSample = 50
centerImgs = np.array([load_in_img(img_location) for img_location in track_log['Center'][0:numSample]], dtype=np.float32)
leftImgs = np.array([load_in_img(img_location) for img_location in track_log['Left'][0:numSample]], dtype=np.float32)
rightImgs = np.array([load_in_img(img_location) for img_location in track_log['Right'][0:numSample]], dtype=np.float32)

# %%
#check the image size
print(centerImgs.shape)
print(leftImgs.shape)
print(rightImgs.shape)
# Out:
# (50, 66, 200, 3)
# (50, 66, 200, 3)
# (50, 66, 200, 3)

# %%
#data augmentation
import cv2
import numpy as np

# flip images horizontally
def random_flip_image(img, angle):
    if np.random.rand() < 0.5:
        img = cv2.flip(img, 1)
        angle = -angle
    return img, angle

def modify_brightness(img):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    brightness_mul = np.random.uniform(low=0.3, high=1.0)
    img[:,:,2] = img[:,:,2]*brightness_mul
    img[:,:,2][img[:,:,2]>255] = 255
    img = cv2.cvtColor(img, cv2.COLOR_HSV2BGR)
    return img

def random_shadow(img):
    img = cv2.cvtColor(img, cv2.COLOR_RGB2HLS)
    
    # (x1, y1) and (x2, y2) forms a line
    # xm, ym gives all the locations of the image
    x1, y1 = 200 * np.random.rand(), 0
    x2, y2 = 200 * np.random.rand(), 66
    xm, ym = np.mgrid[0:66, 0:200]
    
    # create the mask area
    mask = np.zeros_like(img[:, :, 1])
    mask[(ym - y1) * (x2 - x1) - (y2 - y1) * (xm - x1) > 0] = 1

    # choose which side should have shadow and adjust saturation
    cond = mask == np.random.randint(2)
    random_bright = np.random.uniform(low=0.2, high=0.7)

    # adjust Saturation in HLS(Hue, Light, Saturation)
    img[:, :, 1][cond] = img[:, :, 1][cond] * random_bright
    
    img = cv2.cvtColor(img, cv2.COLOR_HLS2RGB)
    return img

def random_translate(img, angle, range_x=100, range_y=10):
    trans_x = range_x * (np.random.rand() - 0.5)
    trans_y = range_y * (np.random.rand() - 0.5)
    angle += trans_x * 0.002
    trans_m = np.float32([[1, 0, trans_x], [0, 1, trans_y]])
    height, width = img.shape[:2]
    img = cv2.warpAffine(img, trans_m, (width, height))
    return img, angle

def process_image(img, angle):
    img = modify_brightness(img)
    img = random_shadow(img)
    img, angle = random_flip_image(img, angle)
    img, angle = random_translate(img, angle)
    return img, angle

# %%
import sklearn

#load in the img and angle data
def load_data(img_sample, ang_sample, correction = 0.20):

    img_center = load_in_img(img_sample)
    img_left = load_in_img(img_sample)
    img_right =load_in_img(img_sample)
    
    angle_center = float(ang_sample) * (1 + np.random.uniform(-0.10,0.10))
    angle_left = angle_center + correction
    angle_right = angle_center - correction

    return (img_center, img_left, img_right), (angle_center, angle_left, angle_right)

#Generator
def generator(samples, batch_size=64):
    num_samples = len(samples)
    while 1: 
        sklearn.utils.shuffle(samples)
        for offset in range(0, num_samples, batch_size):
            batch_samples = samples[offset:offset + batch_size]       
            images = []
            angles = []
            for img, ang in zip(batch_samples['Center'], batch_samples['Steering Angle']):
                image, angle = load_data(img, ang)
                for item in zip(image,angle): #iterate camera images and steering angles
                    #print(item[0])
                    aug_image, aug_angle = process_image(item[0], item[1])
                    if abs(aug_angle) > 0.05:
                        images.append(aug_image)
                        angles.append(aug_angle)
                        #print(aug_image.shape)
                
            X_train = np.array(images)
            y_train = np.array(angles)
            yield X_train, y_train

# %%
#split the log into train_samples and validation_samples
from sklearn.model_selection import train_test_split
train_samples, validation_samples = train_test_split(track_log, test_size=0.2)

# %%
#see if generator work
import matplotlib.pyplot as plt
iterator = generator(train_samples, 64)
sample_images, sample_steerings = iterator.__next__()

plt.subplots(figsize=(20, 5))
for i in range(10):
    plt.subplot(2, 5, i+1)
    plt.axis('off')
    plt.title("Steering: {:.4f}".format(sample_steerings[i]))
    plt.imshow(sample_images[i])
plt.show()

# %%
#NVIDIA's model
import pickle
import numpy as np
import math
from keras.utils import np_utils
from keras.layers import Lambda, Conv2D, MaxPooling2D, Dropout, Dense, Flatten
from keras.optimizers import SGD, Adam
from keras.models import Sequential

INPUT_SHAPE = (66, 200, 3)
DROP_PROB = 0.7

model = Sequential()
model.add(Lambda(lambda x: x/127.5-1.0,input_shape=INPUT_SHAPE))
model.add(Conv2D(24, 5, 5, activation='relu', subsample=(2, 2)))
model.add(Conv2D(36, 5, 5, activation='relu', subsample=(2, 2)))
model.add(Conv2D(48, 5, 5, activation='relu', subsample=(2, 2)))
model.add(Conv2D(64, 3, 3, activation='relu'))
model.add(Conv2D(64, 3, 3, activation='relu'))
model.add(Dropout(DROP_PROB))
model.add(Flatten())
model.add(Dense(100))
model.add(Dense(50))
model.add(Dense(10))
model.add(Dense(1))
# Out:
# Using TensorFlow backend.

# %%
# model summary 
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# lambda_1 (Lambda)                (None, 66, 200, 3)    0           lambda_input_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)  (None, 31, 98, 24)    1824        lambda_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_2 (Convolution2D)  (None, 14, 47, 36)    21636       convolution2d_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_3 (Convolution2D)  (None, 5, 22, 48)     43248       convolution2d_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_4 (Convolution2D)  (None, 3, 20, 64)     27712       convolution2d_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_5 (Convolution2D)  (None, 1, 18, 64)     36928       convolution2d_4[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 1, 18, 64)     0           convolution2d_5[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)              (None, 1152)          0           dropout_1[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 100)           115300      flatten_1[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                  (None, 50)            5050        dense_1[0][0]
# ____________________________________________________________________________________________________
# dense_3 (Dense)                  (None, 10)            510         dense_2[0][0]
# ____________________________________________________________________________________________________
# dense_4 (Dense)                  (None, 1)             11          dense_3[0][0]
# ====================================================================================================
# Total params: 252,219
# Trainable params: 252,219
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
model.compile(optimizer="adam", loss="mse")

#assign the specific GPU
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# 自動增長 GPU 記憶體用量
#import tensorflow as tf
#gpu_options = tf.GPUOptions(allow_growth=True)
#sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))

# %%
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, LambdaCallback, Callback
import keras

# compile and train the model using the generator function


for time in range(10):
    train_generator = generator(train_samples, 64)
    validation_generator = generator(validation_samples, 64)
    
    history_object = model.fit_generator(
                                     train_generator, 
                                     samples_per_epoch=32000,
                                     validation_data=validation_generator,
                                     nb_val_samples=len(validation_samples),
                                     nb_epoch=10,
                                     verbose=2,
                                     callbacks=[
                                         ModelCheckpoint(filepath="time"+str(time)+".h5", verbose=1, save_best_only=True),
                                         keras.callbacks.TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True)
                                     ])
    
    
    print('Time ',time+1)
# Out:
# Epoch 1/10
# /opt/miniconda/lib/python3.5/site-packages/keras/engine/training.py:1527: UserWarning: Epoch comprised more than `samples_per_epoch` samples, which might affect learning results. Set `samples_per_epoch` correctly to avoid this warning.
#   warnings.warn('Epoch comprised more than '
# Epoch 00000: val_loss improved from inf to 0.11453, saving model to time0.h5
# 49s - loss: 0.1291 - val_loss: 0.1145
# Epoch 2/10
# Epoch 00001: val_loss improved from 0.11453 to 0.10880, saving model to time0.h5
# 46s - loss: 0.1141 - val_loss: 0.1088
# Epoch 3/10
# Epoch 00002: val_loss improved from 0.10880 to 0.10242, saving model to time0.h5
# 46s - loss: 0.1111 - val_loss: 0.1024
# Epoch 4/10
# Epoch 00003: val_loss improved from 0.10242 to 0.10198, saving model to time0.h5
# 46s - loss: 0.1111 - val_loss: 0.1020
# Epoch 5/10
# Epoch 00004: val_loss improved from 0.10198 to 0.09884, saving model to time0.h5
# 46s - loss: 0.1033 - val_loss: 0.0988
# Epoch 6/10
# Epoch 00005: val_loss improved from 0.09884 to 0.09612, saving model to time0.h5
# 46s - loss: 0.1006 - val_loss: 0.0961
# Epoch 7/10
# Epoch 00006: val_loss did not improve
# 47s - loss: 0.1004 - val_loss: 0.0988
# Epoch 8/10
# Epoch 00007: val_loss improved from 0.09612 to 0.09044, saving model to time0.h5
# 46s - loss: 0.0998 - val_loss: 0.0904
# Epoch 9/10
# Epoch 00008: val_loss did not improve
# 46s - loss: 0.0971 - val_loss: 0.0928
# Epoch 10/10
# Epoch 00009: val_loss improved from 0.09044 to 0.08975, saving model to time0.h5
# 46s - loss: 0.0954 - val_loss: 0.0898
# Time  1
# Epoch 1/10
# Epoch 00000: val_loss improved from inf to 0.08568, saving model to time1.h5
# 48s - loss: 0.0947 - val_loss: 0.0857
# Epoch 2/10
# Epoch 00001: val_loss did not improve
# 46s - loss: 0.0918 - val_loss: 0.0866
# Epoch 3/10
# Epoch 00002: val_loss improved from 0.08568 to 0.08289, saving model to time1.h5
# 46s - loss: 0.0891 - val_loss: 0.0829
# Epoch 4/10
# Epoch 00003: val_loss improved from 0.08289 to 0.08128, saving model to time1.h5
# 46s - loss: 0.0879 - val_loss: 0.0813
# Epoch 5/10
# Epoch 00004: val_loss improved from 0.08128 to 0.08073, saving model to time1.h5
# 47s - loss: 0.0875 - val_loss: 0.0807
# Epoch 6/10
# Epoch 00005: val_loss improved from 0.08073 to 0.07814, saving model to time1.h5
# 47s - loss: 0.0864 - val_loss: 0.0781
# Epoch 7/10
# Epoch 00006: val_loss did not improve
# 46s - loss: 0.0834 - val_loss: 0.0813
# Epoch 8/10
# Epoch 00007: val_loss improved from 0.07814 to 0.07514, saving model to time1.h5
# 47s - loss: 0.0840 - val_loss: 0.0751
# Epoch 9/10
# Epoch 00008: val_loss did not improve
# 46s - loss: 0.0828 - val_loss: 0.0765
# Epoch 10/10
# Epoch 00009: val_loss did not improve
# 46s - loss: 0.0817 - val_loss: 0.0776
# Time  2
# Epoch 1/10
# Epoch 00000: val_loss improved from inf to 0.07218, saving model to time2.h5
# 49s - loss: 0.0807 - val_loss: 0.0722
# Epoch 2/10
# Epoch 00001: val_loss did not improve
# 47s - loss: 0.0777 - val_loss: 0.0726
# Epoch 3/10
# Epoch 00002: val_loss did not improve
# 46s - loss: 0.0792 - val_loss: 0.0738
# Epoch 4/10
# Epoch 00003: val_loss improved from 0.07218 to 0.07017, saving model to time2.h5
# 47s - loss: 0.0773 - val_loss: 0.0702
# Epoch 5/10
# Epoch 00004: val_loss did not improve
# 46s - loss: 0.0753 - val_loss: 0.0712
# Epoch 6/10
# Epoch 00005: val_loss did not improve
# 47s - loss: 0.0777 - val_loss: 0.0807
# Epoch 7/10
# Epoch 00006: val_loss did not improve
# 46s - loss: 0.0753 - val_loss: 0.0720
# Epoch 8/10
# Epoch 00007: val_loss improved from 0.07017 to 0.06742, saving model to time2.h5
# 46s - loss: 0.0744 - val_loss: 0.0674
# Epoch 9/10
# Epoch 00008: val_loss improved from 0.06742 to 0.06606, saving model to time2.h5
# 47s - loss: 0.0745 - val_loss: 0.0661
# Epoch 10/10
# Epoch 00009: val_loss did not improve
# 46s - loss: 0.0730 - val_loss: 0.0692
# Time  3
# Epoch 1/10
# Epoch 00000: val_loss improved from inf to 0.06250, saving model to time3.h5
# 48s - loss: 0.0745 - val_loss: 0.0625
# Epoch 2/10
# Epoch 00001: val_loss did not improve
# 46s - loss: 0.0713 - val_loss: 0.0668
# Epoch 3/10
# Epoch 00002: val_loss did not improve
# 46s - loss: 0.0732 - val_loss: 0.0690
# Epoch 4/10
# Epoch 00003: val_loss did not improve
# 46s - loss: 0.0716 - val_loss: 0.0632
# Epoch 5/10
# Epoch 00004: val_loss did not improve
# 47s - loss: 0.0720 - val_loss: 0.0688
# Epoch 6/10
# Epoch 00005: val_loss did not improve
# 46s - loss: 0.0728 - val_loss: 0.0677
# Epoch 7/10
# Epoch 00006: val_loss did not improve
# 46s - loss: 0.0722 - val_loss: 0.0651
# Epoch 8/10
# Epoch 00007: val_loss did not improve
# 46s - loss: 0.0707 - val_loss: 0.0648
# Epoch 9/10
# Epoch 00008: val_loss did not improve
# 46s - loss: 0.0712 - val_loss: 0.0632
# Epoch 10/10
# Epoch 00009: val_loss did not improve
# 46s - loss: 0.0698 - val_loss: 0.0700
# Time  4
# Epoch 1/10
# Epoch 00000: val_loss improved from inf to 0.06290, saving model to time4.h5
# 48s - loss: 0.0704 - val_loss: 0.0629
# Epoch 2/10
# Epoch 00001: val_loss did not improve
# 46s - loss: 0.0685 - val_loss: 0.0633
# Epoch 3/10
# Epoch 00002: val_loss improved from 0.06290 to 0.06094, saving model to time4.h5
# 46s - loss: 0.0689 - val_loss: 0.0609
# Epoch 4/10
# Epoch 00003: val_loss did not improve
# 46s - loss: 0.0694 - val_loss: 0.0639
# Epoch 5/10
# Epoch 00004: val_loss did not improve
# 46s - loss: 0.0690 - val_loss: 0.0657
# Epoch 6/10
# Epoch 00005: val_loss did not improve
# 47s - loss: 0.0694 - val_loss: 0.0620
# Epoch 7/10
# Epoch 00006: val_loss did not improve
# 46s - loss: 0.0672 - val_loss: 0.0666
# Epoch 8/10
# Epoch 00007: val_loss did not improve
# 47s - loss: 0.0668 - val_loss: 0.0633
# Epoch 9/10
# Epoch 00008: val_loss did not improve
# 46s - loss: 0.0680 - val_loss: 0.0618
# Epoch 10/10
# Epoch 00009: val_loss did not improve
# 46s - loss: 0.0680 - val_loss: 0.0656
# Time  5
# Epoch 1/10
# Epoch 00000: val_loss improved from inf to 0.05969, saving model to time5.h5
# 49s - loss: 0.0672 - val_loss: 0.0597
# Epoch 2/10
# Epoch 00001: val_loss did not improve
# 46s - loss: 0.0673 - val_loss: 0.0643
# Epoch 3/10
# Epoch 00002: val_loss did not improve
# 46s - loss: 0.0678 - val_loss: 0.0608
# Epoch 4/10
# Epoch 00003: val_loss did not improve
# 47s - loss: 0.0662 - val_loss: 0.0644
# Epoch 5/10
# Epoch 00004: val_loss did not improve
# 46s - loss: 0.0664 - val_loss: 0.0672
# Epoch 6/10
# Epoch 00005: val_loss did not improve
# 46s - loss: 0.0668 - val_loss: 0.0631
# Epoch 7/10
# Epoch 00006: val_loss did not improve
# 46s - loss: 0.0677 - val_loss: 0.0631
# Epoch 8/10
# Epoch 00007: val_loss did not improve
# 46s - loss: 0.0659 - val_loss: 0.0652
# Epoch 9/10
# Epoch 00008: val_loss did not improve
# 46s - loss: 0.0667 - val_loss: 0.0605
# Epoch 10/10
# Epoch 00009: val_loss did not improve
# 46s - loss: 0.0675 - val_loss: 0.0649
# Time  6
# Epoch 1/10
# Epoch 00000: val_loss improved from inf to 0.05855, saving model to time6.h5
# 48s - loss: 0.0654 - val_loss: 0.0586
# Epoch 2/10
# Epoch 00001: val_loss did not improve
# 46s - loss: 0.0657 - val_loss: 0.0618
# Epoch 3/10
# Epoch 00002: val_loss did not improve
# 47s - loss: 0.0648 - val_loss: 0.0604
# Epoch 4/10
# Epoch 00003: val_loss did not improve
# 46s - loss: 0.0640 - val_loss: 0.0596
# Epoch 5/10
# Epoch 00004: val_loss did not improve
# 46s - loss: 0.0642 - val_loss: 0.0620
# Epoch 6/10
# Epoch 00005: val_loss did not improve
# 46s - loss: 0.0668 - val_loss: 0.0598
# Epoch 7/10
# Epoch 00006: val_loss did not improve
# 46s - loss: 0.0648 - val_loss: 0.0611
# Epoch 8/10
# Epoch 00007: val_loss did not improve
# 46s - loss: 0.0653 - val_loss: 0.0606
# Epoch 9/10
# Epoch 00008: val_loss improved from 0.05855 to 0.05668, saving model to time6.h5
# 46s - loss: 0.0640 - val_loss: 0.0567
# Epoch 10/10
# Epoch 00009: val_loss did not improve
# 46s - loss: 0.0638 - val_loss: 0.0593
# Time  7
# Epoch 1/10
# Epoch 00000: val_loss improved from inf to 0.05840, saving model to time7.h5
# 48s - loss: 0.0638 - val_loss: 0.0584
# Epoch 2/10
# Epoch 00001: val_loss did not improve
# 46s - loss: 0.0636 - val_loss: 0.0586
# Epoch 3/10
# Epoch 00002: val_loss did not improve
# 46s - loss: 0.0636 - val_loss: 0.0632
# Epoch 4/10
# Epoch 00003: val_loss improved from 0.05840 to 0.05778, saving model to time7.h5
# 46s - loss: 0.0628 - val_loss: 0.0578
# Epoch 5/10
# Epoch 00004: val_loss did not improve
# 47s - loss: 0.0633 - val_loss: 0.0605
# Epoch 6/10
# Epoch 00005: val_loss did not improve
# 46s - loss: 0.0641 - val_loss: 0.0603
# Epoch 7/10
# Epoch 00006: val_loss did not improve
# 46s - loss: 0.0626 - val_loss: 0.0593
# Epoch 8/10
# Epoch 00007: val_loss improved from 0.05778 to 0.05639, saving model to time7.h5
# 46s - loss: 0.0627 - val_loss: 0.0564
# Epoch 9/10
# Epoch 00008: val_loss did not improve
# 47s - loss: 0.0625 - val_loss: 0.0586
# Epoch 10/10
# Epoch 00009: val_loss did not improve
# 47s - loss: 0.0636 - val_loss: 0.0619
# Time  8
# Epoch 1/10
# Epoch 00000: val_loss improved from inf to 0.05847, saving model to time8.h5
# 49s - loss: 0.0626 - val_loss: 0.0585
# Epoch 2/10
# Epoch 00001: val_loss did not improve
# 47s - loss: 0.0635 - val_loss: 0.0618
# Epoch 3/10
# Epoch 00002: val_loss did not improve
# 46s - loss: 0.0635 - val_loss: 0.0586
# Epoch 4/10
# Epoch 00003: val_loss did not improve
# 46s - loss: 0.0619 - val_loss: 0.0587
# Epoch 5/10
# Epoch 00004: val_loss did not improve
# 46s - loss: 0.0625 - val_loss: 0.0594
# Epoch 6/10
# Epoch 00005: val_loss did not improve
# 46s - loss: 0.0627 - val_loss: 0.0621
# Epoch 7/10
# Epoch 00006: val_loss did not improve
# 46s - loss: 0.0615 - val_loss: 0.0608
# Epoch 8/10
# Epoch 00007: val_loss improved from 0.05847 to 0.05675, saving model to time8.h5
# 46s - loss: 0.0628 - val_loss: 0.0568
# Epoch 9/10
# Epoch 00008: val_loss did not improve
# 46s - loss: 0.0618 - val_loss: 0.0574
# Epoch 10/10
# Epoch 00009: val_loss did not improve
# 46s - loss: 0.0621 - val_loss: 0.0603
# Time  9
# Epoch 1/10
# Epoch 00000: val_loss improved from inf to 0.06015, saving model to time9.h5
# 48s - loss: 0.0620 - val_loss: 0.0602
# Epoch 2/10
# Epoch 00001: val_loss improved from 0.06015 to 0.05887, saving model to time9.h5
# 46s - loss: 0.0616 - val_loss: 0.0589
# Epoch 3/10
# Epoch 00002: val_loss did not improve
# 47s - loss: 0.0623 - val_loss: 0.0598
# Epoch 4/10
# Epoch 00003: val_loss did not improve
# 47s - loss: 0.0618 - val_loss: 0.0604
# Epoch 5/10
# Epoch 00004: val_loss did not improve
# 46s - loss: 0.0620 - val_loss: 0.0601
# Epoch 6/10
# Epoch 00005: val_loss improved from 0.05887 to 0.05797, saving model to time9.h5
# 46s - loss: 0.0616 - val_loss: 0.0580
# Epoch 7/10
# Epoch 00006: val_loss improved from 0.05797 to 0.05671, saving model to time9.h5
# 46s - loss: 0.0618 - val_loss: 0.0567
# Epoch 8/10
# Epoch 00007: val_loss improved from 0.05671 to 0.05660, saving model to time9.h5
# 46s - loss: 0.0610 - val_loss: 0.0566
# Epoch 9/10
# Epoch 00008: val_loss improved from 0.05660 to 0.05645, saving model to time9.h5
# 46s - loss: 0.0607 - val_loss: 0.0565
# Epoch 10/10
# Epoch 00009: val_loss did not improve
# 46s - loss: 0.0609 - val_loss: 0.0591
# Time  10

# %%
# summarize history for loss
plt.plot(history_object.history['loss'])
plt.plot(history_object.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
import time, os, fnmatch, shutil
def save_model(model_name):
    t = time.localtime()
    timestamp = time.strftime('%b-%d-%Y_%H-%M-%S', t)
    model_name = (model_name  + '_' + timestamp + '.h5')
    
    return model_name

h5_output = save_model("model") 
model.save(h5_output)
print("Model saved")
# Out:
# Model saved

# %%
#data selection -> make the zero Steering Angle less
#idea from : https://github.com/budmitr
non_zero_samples =  training_log.loc[training_log['Steering Angle'] != 0.0,:] 
zero_samples =  training_log.loc[training_log['Steering Angle'] == 0.0,:]  # 
print(training_log.shape, non_zero_samples.shape, zero_samples.shape) 

fraction = 0.2
new_training_log = pd.concat([non_zero_samples, zero_samples.sample(frac=fraction)], ignore_index=True)

#print(newDrivingLog)
training_log = new_training_log

print(training_log['Steering Angle'].shape)

# %%
# save the model
import json
#import simplejson
jsonString = model.to_json() # json Model
with open('./model.json', 'w') as outFile:
    outFile.write(jsonString)
    # json.dump(jsonString, outFile)

model.save_weights('./model.h5') #  HDF5 file

# %%
# load the model
from keras.models import model_from_json
jsonFile = './model.json'
with open(jsonFile, 'r') as jfile:
    #model = model_from_json(json.load(jfile))
    model = model_from_json(jfile.read())
model.compile("adam", "mse")
weights_file = jsonFile.replace('json', 'h5')
model.load_weights(weights_file)
